# %% [markdown]
# <a href="https://colab.research.google.com/github/Rizwan-Ahmed-Arain/PIAIC-projects-Quater-2/blob/main/hello_gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain-google-genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.6 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade --force-reinstall langchain-google-genai # Reinstalling package to address potential installation issue or corrupted package.
import langchain_google_genai as genai # Now importing the package, expected to work without errors.
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.8/160.8 kB 14.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.0/760.0 kB 52.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.9/411.9 kB 37.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 37.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 78.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.6/158.6 kB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 kB 21.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.9/326.9 kB 27.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 7.4 MB/s eta 0:00:00
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
from google.colab import userdata
userdata.get('GOOGLE_API_KEY')
# Out:
# 'AIzaSyDz6QinzuY7rzDy7DuJtnNzsL_N-FQaQrs'

# %%
# Ensure you have imported the relevant library
# from some_module import ChatGoogleGenerativeAI

# Define the API key
GOOGLE_API_KEY = "AIzaSyDz6QinzuY7rzDy7DuJtnNzsL_N-FQaQrs"  # Replace with your actual API key

# Initialize the model
model = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
    api_key=GOOGLE_API_KEY
)

# %%
response = model.invoke("how to do swiming")
print(response.content)
# Out:
# Learning to swim takes time and practice, but it's a rewarding skill! Here's a breakdown of how to learn, focusing on safety and progression:
#
# **1. Getting Comfortable in the Water:**
#
# * **Start shallow:** Begin in water that's only waist-deep or chest-deep.  Get used to the feeling of the water on your skin.
# * **Practice blowing bubbles:** This helps you get comfortable with putting your face in the water. Exhale slowly through your mouth and nose while submerged.
# * **Submerging your face:** Gradually increase the time you spend with your face in the water.  Practice opening your eyes underwater (it takes some getting used to).
# * **Kicking:** While holding onto the side of the pool, practice kicking with your legs. Keep your legs relatively straight and kick from your hips, not just your knees.  Try different kicks like flutter kicks (used in freestyle) and frog kicks (used in breaststroke).
# ...
